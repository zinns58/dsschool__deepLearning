# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Generate Dataset

# %%
x1 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x1.shape)
x1[0:10]
# Out:
# (100,)
# array([-0.6888204 ,  0.74322563,  0.11266198,  0.6926378 , -0.51630978,
#         0.53374988,  0.92690106, -0.11362144, -0.53037321,  0.65806396])

# %%
x2 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x2.shape)
x2[0:10]
# Out:
# (100,)
# array([-0.2361318 ,  0.14189175, -0.42405645,  0.46884816,  0.10603602,
#        -0.55480588, -0.62853307,  0.93706743,  0.14320808, -0.84757203])

# %%
y = 0.3 * x1 + 0.5 * x2 + 0.1

y = (y > 0).astype('int')

print(y.shape)
y[0:10]
# Out:
# (100,)
# array([0, 1, 0, 1, 0, 0, 1, 1, 1, 0])

# %%
plt.scatter(x1, x2, c=y)

# %% [markdown]
# # Define Sigmoid

# %%
def sigmoid(n):
    return 1 / (1 + np.exp(-n))

xx = np.linspace(start=-9, stop=+9)
yy = sigmoid(xx)

plt.plot(xx, yy)

# %% [markdown]
# # Gradient Descent

# %%
num_epoch = 100
learning_rate = 1.0

w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

for epoch in range(num_epoch):
    y_predict = w1 * x1 + w2 * x2 + b
    y_predict = sigmoid(y_predict)
    
    predict = (y_predict >= 0.5).astype('int')
    accuracy = (predict == y).mean()
    
    if epoch % 10 == 0:
        print("{:2} accuracy = {:.6f}".format(epoch, accuracy))
        
    w1 = w1 - learning_rate * ((y_predict - y) * x1).mean()
    w2 = w2 - learning_rate * ((y_predict - y) * x2).mean()
    b = b - learning_rate * (y_predict - y).mean()
    
print("---" * 10)
print("{:2} accuracy = {:.6f}".format(epoch, accuracy))
# Out:
#  0 accuracy = 0.520000
# 10 accuracy = 0.920000
# 20 accuracy = 0.950000
# 30 accuracy = 0.950000
# 40 accuracy = 0.950000
# 50 accuracy = 0.950000
# 60 accuracy = 0.950000
# 70 accuracy = 0.960000
# 80 accuracy = 0.960000
# 90 accuracy = 0.960000
# ------------------------------
# 99 accuracy = 0.960000

# %%
import pandas as pd

# %%
y_predict = w1 * x1 + w2 * x2 + b
y_predict = sigmoid(y_predict)
y_predict = (y_predict >= 0.5).astype('int')

result = pd.DataFrame({'x1': x1, 'x2': x2, 'y(actual)': y, 'y(predict)': y_predict})

result
# Out:
#           x1        x2  y(actual)  y(predict)
# 0  -0.688820 -0.236132          0           0
# 1   0.743226  0.141892          1           1
# 2   0.112662 -0.424056          0           0
# 3   0.692638  0.468848          1           1
# 4  -0.516310  0.106036          0           1
# 5   0.533750 -0.554806          0           0
# 6   0.926901 -0.628533          1           1
# 7  -0.113621  0.937067          1           1
# 8  -0.530373  0.143208          1           1
# 9   0.658064 -0.847572          0           0
# 10 -0.807055 -0.539806          0           0
# 11  0.314281  0.603761          1           1
# 12 -0.599219 -0.718602          0           0
# 13  0.300583 -0.158186          1           1
# 14 -0.527066  0.481077          1           1
# 15 -0.369055 -0.953030          0           0
# 16  0.070030  0.830205          1           1
# 17 -0.792152 -0.939832          0           0
# 18 -0.423136  0.142930          1           1
# 19 -0.115929 -0.741749          0           0
# 20  0.772264  0.779080          1           1
# 21 -0.326591  0.526528          1           1
# 22 -0.602067 -0.403646          0           0
# 23  0.309205 -0.812144          0           0
# 24  0.859319  0.862431          1           1
# 25 -0.992711 -0.053693          0           0
# 26  0.565844 -0.944074          0           0
# 27  0.449384  0.662958          1           1
# 28  0.863379  0.815516          1           1
# 29  0.548662  0.042230          1           1
# ..       ...       ...        ...         ...
# 70  0.180597 -0.473355          0           0
# 71 -0.490243 -0.708198          0           0
# 72 -0.793470 -0.676074          0           0
# 73  0.617415 -0.565001          1           0
# 74 -0.413245 -0.854700          0           0
# 75 -0.748759 -0.988036          0           0
# 76 -0.681206 -0.215315          0           0
# 77 -0.086906 -0.938467          0           0
# 78 -0.515781  0.109663          1           1
# 79 -0.740679 -0.364389          0           0
# 80  0.771325 -0.833106          0           0
# 81 -0.670164 -0.082507          0           0
# 82 -0.620990  0.834007          1           1
# 83  0.613092  0.596343          1           1
# 84 -0.150946 -0.161035          0           0
# 85  0.181878  0.341339          1           1
# 86 -0.386218 -0.991619          0           0
# 87  0.476860 -0.234441          1           1
# 88  0.556808  0.752620          1           1
# 89  0.812227 -0.241148          1           1
# 90  0.650424 -0.456770          1           1
# 91 -0.514775  0.067262          0           1
# 92 -0.614862 -0.064014          0           0
# 93  0.077944 -0.323842          0           0
# 94 -0.228065 -0.656417          0           0
# 95  0.245523 -0.430448          0           0
# 96  0.233526  0.276463          1           1
# 97  0.029058 -0.100697          1           1
# 98 -0.319073  0.749618          1           1
# 99 -0.708126  0.659602          1           1
#
# [100 rows x 4 columns]
